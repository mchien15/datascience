# %%
import pandas as pd

# %%
from utils import load_data, get_similar_players_cosine, get_similar_players_knn, compare_players
# Out:
# 2023-12-19 12:55:19.001 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
df, scaled_df, similarity_df = load_data()
# Out:
# 2023-12-19 13:07:20.830
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/asus/anaconda3/envs/datamining/lib/python3.8/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2023-12-19 13:07:20.832 No runtime found, using MemoryCacheStorageManager
# /home/asus/stuDYING/IT/DataScience/project/get_data/get_data.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('SELECT * FROM all_leagues',conn)
# ---------------------------------------------------------------------------
# CacheStorageKeyNotFoundError              Traceback (most recent call last)
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/storage/in_memory_cache_storage_wrapper.py:87, in InMemoryCacheStorageWrapper.get(self, key)
#      86 try:
# ---> 87     entry_bytes = self._read_from_mem_cache(key)
#      88 except CacheStorageKeyNotFoundError:
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/storage/in_memory_cache_storage_wrapper.py:137, in InMemoryCacheStorageWrapper._read_from_mem_cache(self, key)
#     136 _LOGGER.debug("Memory cache MISS: %s", key)
# --> 137 raise CacheStorageKeyNotFoundError("Key not found in mem cache")
#
# CacheStorageKeyNotFoundError: Key not found in mem cache
#
# During handling of the above exception, another exception occurred:
#
# CacheStorageKeyNotFoundError              Traceback (most recent call last)
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/cache_data_api.py:634, in DataCache.read_result(self, key)
#     633 try:
# --> 634     pickled_entry = self.storage.get(key)
#     635 except CacheStorageKeyNotFoundError as e:
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/storage/in_memory_cache_storage_wrapper.py:89, in InMemoryCacheStorageWrapper.get(self, key)
#      88 except CacheStorageKeyNotFoundError:
# ---> 89     entry_bytes = self._persist_storage.get(key)
#      90     self._write_to_mem_cache(key, entry_bytes)
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/storage/dummy_cache_storage.py:48, in DummyCacheStorage.get(self, key)
#      44 """
#      45 Dummy gets the value for a given key,
#      46 always raises an CacheStorageKeyNotFoundError
#      47 """
# ---> 48 raise CacheStorageKeyNotFoundError("Key not found in dummy cache")
#
# CacheStorageKeyNotFoundError: Key not found in dummy cache
#
# The above exception was the direct cause of the following exception:
#
# CacheKeyNotFoundError                     Traceback (most recent call last)
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/cache_utils.py:264, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs)
#     263 try:
# --> 264     cached_result = cache.read_result(value_key)
#     265     return self._handle_cache_hit(cached_result)
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/cache_data_api.py:636, in DataCache.read_result(self, key)
#     635 except CacheStorageKeyNotFoundError as e:
# --> 636     raise CacheKeyNotFoundError(str(e)) from e
#     637 except CacheStorageError as e:
#
# CacheKeyNotFoundError: Key not found in dummy cache
#
# During handling of the above exception, another exception occurred:
#
# CacheStorageKeyNotFoundError              Traceback (most recent call last)
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/storage/in_memory_cache_storage_wrapper.py:87, in InMemoryCacheStorageWrapper.get(self, key)
#      86 try:
# ---> 87     entry_bytes = self._read_from_mem_cache(key)
#      88 except CacheStorageKeyNotFoundError:
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/storage/in_memory_cache_storage_wrapper.py:137, in InMemoryCacheStorageWrapper._read_from_mem_cache(self, key)
#     136 _LOGGER.debug("Memory cache MISS: %s", key)
# --> 137 raise CacheStorageKeyNotFoundError("Key not found in mem cache")
#
# CacheStorageKeyNotFoundError: Key not found in mem cache
#
# During handling of the above exception, another exception occurred:
#
# CacheStorageKeyNotFoundError              Traceback (most recent call last)
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/cache_data_api.py:634, in DataCache.read_result(self, key)
#     633 try:
# --> 634     pickled_entry = self.storage.get(key)
#     635 except CacheStorageKeyNotFoundError as e:
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/storage/in_memory_cache_storage_wrapper.py:89, in InMemoryCacheStorageWrapper.get(self, key)
#      88 except CacheStorageKeyNotFoundError:
# ---> 89     entry_bytes = self._persist_storage.get(key)
#      90     self._write_to_mem_cache(key, entry_bytes)
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/storage/dummy_cache_storage.py:48, in DummyCacheStorage.get(self, key)
#      44 """
#      45 Dummy gets the value for a given key,
#      46 always raises an CacheStorageKeyNotFoundError
#      47 """
# ---> 48 raise CacheStorageKeyNotFoundError("Key not found in dummy cache")
#
# CacheStorageKeyNotFoundError: Key not found in dummy cache
#
# The above exception was the direct cause of the following exception:
#
# CacheKeyNotFoundError                     Traceback (most recent call last)
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/cache_utils.py:312, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     311 try:
# --> 312     cached_result = cache.read_result(value_key)
#     313     # Another thread computed the value before us. Early exit!
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/cache_data_api.py:636, in DataCache.read_result(self, key)
#     635 except CacheStorageKeyNotFoundError as e:
# --> 636     raise CacheKeyNotFoundError(str(e)) from e
#     637 except CacheStorageError as e:
#
# CacheKeyNotFoundError: Key not found in dummy cache
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df, scaled_df, similarity_df = load_data()
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/cache_utils.py:212, in make_cached_func_wrapper.<locals>.wrapper(*args, **kwargs)
#     210 @functools.wraps(info.func)
#     211 def wrapper(*args, **kwargs):
# --> 212     return cached_func(*args, **kwargs)
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/cache_utils.py:241, in CachedFunc.__call__(self, *args, **kwargs)
#     239 if self._info.show_spinner or isinstance(self._info.show_spinner, str):
#     240     with spinner(message, cache=True):
# --> 241         return self._get_or_create_cached_value(args, kwargs)
#     242 else:
#     243     return self._get_or_create_cached_value(args, kwargs)
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/cache_utils.py:267, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs)
#     265     return self._handle_cache_hit(cached_result)
#     266 except CacheKeyNotFoundError:
# --> 267     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/streamlit/runtime/caching/cache_utils.py:321, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     316 except CacheKeyNotFoundError:
#     317     # We acquired the lock before any other thread. Compute the value!
#     318     with self._info.cached_message_replay_ctx.calling_cached_function(
#     319         self._info.func, self._info.allow_widgets
#     320     ):
# --> 321         computed_value = self._info.func(*func_args, **func_kwargs)
#     323     # We've computed our value, and now we need to write it back to the cache
#     324     # along with any "replay messages" that were generated during value computation.
#     325     messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# File ~/stuDYING/IT/DataScience/project/utils.py:31, in load_data()
#      28 @st.cache_data
#      29 def load_data():
# ---> 31     df = process_data()
#      33     numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns
#      34     numerical_cols = numerical_cols[numerical_cols != 'Min']
#
# File ~/stuDYING/IT/DataScience/project/prc.py:6, in process_data()
#       5 def process_data():
# ----> 6     d = data()
#       7     new_headers = [
#       8         "Date", "Name", "Round", "Venue", "Result", "Squad", "Opponent", "Start", "Pos",
#       9         "Min", "Cmp", "PassAtt", "CmpPct", "PassTotDist", "PassPrgDist", "Cmp1", "Att1",
#    (...)
#      19         "npxG"
#      20     ]
#      22     d.columns = new_headers
#
# File ~/stuDYING/IT/DataScience/project/get_data/get_data.py:43, in data()
#      28 df = pd.read_sql('SELECT * FROM all_leagues',conn)
#      29 new_headers = [
#      30     "Date", "Name", "Round", "Venue", "Result", "Squad", "Opponent", "Start", "Pos",
#      31     "Min", "Cmp", "PassAtt", "CmpPct", "PassTotDist", "PassPrgDist", "Cmp1", "Att1",
#    (...)
#      41     "npxG"
#      42 ]
# ---> 43 df.columns=new_headers
#      44 # d=process_dataframe(df)
#      45 return df
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/pandas/core/generic.py:6002, in NDFrame.__setattr__(self, name, value)
#    6000 try:
#    6001     object.__getattribute__(self, name)
# -> 6002     return object.__setattr__(self, name, value)
#    6003 except AttributeError:
#    6004     pass
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/pandas/core/generic.py:730, in NDFrame._set_axis(self, axis, labels)
#     725 """
#     726 This is called from the cython code when we set the `index` attribute
#     727 directly, e.g. `series.index = [1, 2, 3]`.
#     728 """
#     729 labels = ensure_index(labels)
# --> 730 self._mgr.set_axis(axis, labels)
#     731 self._clear_item_cache()
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/pandas/core/internals/managers.py:225, in BaseBlockManager.set_axis(self, axis, new_labels)
#     223 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     224     # Caller is responsible for ensuring we have an Index object.
# --> 225     self._validate_set_axis(axis, new_labels)
#     226     self.axes[axis] = new_labels
#
# File ~/anaconda3/envs/datamining/lib/python3.8/site-packages/pandas/core/internals/base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 101 elements, new values have 94 elements
